# %%
pip install app_store_scraper
# Out:
# Requirement already satisfied: app_store_scraper in c:\anaconda3\lib\site-packages (0.3.5)
# Requirement already satisfied: requests==2.23.0 in c:\anaconda3\lib\site-packages (from app_store_scraper) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\anaconda3\lib\site-packages (from requests==2.23.0->app_store_scraper) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\anaconda3\lib\site-packages (from requests==2.23.0->app_store_scraper) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests==2.23.0->app_store_scraper) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests==2.23.0->app_store_scraper) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import json
import time
from tqdm import tqdm
from app_store_scraper import AppStore

# %%
def Extract_reviews(app_name:str, app_id:int): 
  camera_app = AppStore(country='kr', app_name=app_name, app_id=app_id)
  camera_app.review()

  camera_app_reviews = pd.DataFrame(camera_app.reviews).sort_values('date', ascending=False).reset_index(drop=True)
  camera_app_reviews['camera_app'] = app_name
  return camera_app_reviews

# %% [markdown]
# camera_app_platform = {'snow': 1022267439,'meitu': 416048305 }
#
# app_store_reviews = pd.DataFrame()
# for i in tqdm(camera_app_platform):
#   camera_app_reviews = Extract_reviews(i, camera_app_platform[i])
#   app_store_reviews= pd.concat([app_store_reviews, camera_app_reviews], axis=0)
#
# print('Done')

# %%
def Extract_reviews(app_name: str, app_id: int): 
    camera_app = AppStore(country='kr', app_name=app_name, app_id=app_id)
    camera_app.review()

    if 'date' in camera_app.reviews:
        camera_app_reviews = pd.DataFrame(camera_app.reviews).sort_values('date', ascending=False).reset_index(drop=True)
    else:
        # 'date' 열이 없는 경우, 인덱스를 기준으로 정렬합니다.
        camera_app_reviews = pd.DataFrame(camera_app.reviews).sort_index(ascending=False).reset_index(drop=True)
    camera_app_reviews['camera_app'] = app_name
    return camera_app_reviews

camera_app_platform = {'snow': 1022267439, 'meitu': 416048305}

app_store_reviews = pd.DataFrame()
for app_name, app_id in tqdm(camera_app_platform.items()):
    camera_app_reviews = Extract_reviews(app_name, app_id)
    app_store_reviews = pd.concat([app_store_reviews, camera_app_reviews], axis=0)

print('Done')
# Out:
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]2024-04-16 15:36:10,172 [INFO] Base - Initialised: AppStore('kr', 'snow', 1022267439)
# 2024-04-16 15:36:10,172 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/kr/app/snow/id1022267439
# 2024-04-16 15:36:15,526 [INFO] Base - [id:1022267439] Fetched 240 reviews (240 fetched in total)
# 2024-04-16 15:36:21,125 [INFO] Base - [id:1022267439] Fetched 520 reviews (520 fetched in total)
# 2024-04-16 15:36:26,761 [INFO] Base - [id:1022267439] Fetched 800 reviews (800 fetched in total)
# 2024-04-16 15:36:32,526 [INFO] Base - [id:1022267439] Fetched 1060 reviews (1060 fetched in total)
# 2024-04-16 15:36:38,036 [INFO] Base - [id:1022267439] Fetched 1320 reviews (1320 fetched in total)
# 2024-04-16 15:36:43,950 [INFO] Base - [id:1022267439] Fetched 1600 reviews (1600 fetched in total)
# 2024-04-16 15:36:49,501 [INFO] Base - [id:1022267439] Fetched 1860 reviews (1860 fetched in total)
# 2024-04-16 15:36:54,989 [INFO] Base - [id:1022267439] Fetched 2140 reviews (2140 fetched in total)
# 2024-04-16 15:37:00,579 [INFO] Base - [id:1022267439] Fetched 2420 reviews (2420 fetched in total)
# 2024-04-16 15:37:06,387 [INFO] Base - [id:1022267439] Fetched 2700 reviews (2700 fetched in total)
# 2024-04-16 15:37:11,943 [INFO] Base - [id:1022267439] Fetched 2960 reviews (2960 fetched in total)
# 2024-04-16 15:37:17,605 [INFO] Base - [id:1022267439] Fetched 3220 reviews (3220 fetched in total)
# 2024-04-16 15:37:23,137 [INFO] Base - [id:1022267439] Fetched 3500 reviews (3500 fetched in total)
# 2024-04-16 15:37:28,797 [INFO] Base - [id:1022267439] Fetched 3780 reviews (3780 fetched in total)
# 2024-04-16 15:37:34,441 [INFO] Base - [id:1022267439] Fetched 4040 reviews (4040 fetched in total)
# 2024-04-16 15:37:40,234 [INFO] Base - [id:1022267439] Fetched 4300 reviews (4300 fetched in total)
# 2024-04-16 15:37:46,034 [INFO] Base - [id:1022267439] Fetched 4540 reviews (4540 fetched in total)
# 2024-04-16 15:37:51,913 [INFO] Base - [id:1022267439] Fetched 4820 reviews (4820 fetched in total)
# 2024-04-16 15:37:57,565 [INFO] Base - [id:1022267439] Fetched 5080 reviews (5080 fetched in total)
# 2024-04-16 15:38:03,379 [INFO] Base - [id:1022267439] Fetched 5360 reviews (5360 fetched in total)
# 2024-04-16 15:38:08,957 [INFO] Base - [id:1022267439] Fetched 5620 reviews (5620 fetched in total)
# 2024-04-16 15:38:14,477 [INFO] Base - [id:1022267439] Fetched 5880 reviews (5880 fetched in total)
# 2024-04-16 15:38:20,016 [INFO] Base - [id:1022267439] Fetched 6140 reviews (6140 fetched in total)
# 2024-04-16 15:38:25,675 [INFO] Base - [id:1022267439] Fetched 6400 reviews (6400 fetched in total)
# 2024-04-16 15:38:31,347 [INFO] Base - [id:1022267439] Fetched 6680 reviews (6680 fetched in total)
# 2024-04-16 15:38:50,656 [ERROR] Base - Something went wrong: HTTPSConnectionPool(host='amp-api.apps.apple.com', port=443): Max retries exceeded with url: /v1/catalog/kr/apps/1022267439/reviews?l=en-GB&offset=6680&limit=20&platform=web&additionalPlatforms=appletv%2Cipad%2Ciphone%2Cmac (Caused by ResponseError('too many 429 error responses'))
# 2024-04-16 15:38:50,658 [INFO] Base - [id:1022267439] Fetched 6680 reviews (6680 fetched in total)
#  50%|█████████████████████████████████████████▌                                         | 1/2 [02:41<02:41, 161.96s/it]2024-04-16 15:38:52,121 [INFO] Base - Initialised: AppStore('kr', 'meitu', 416048305)
# 2024-04-16 15:38:52,122 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/kr/app/meitu/id416048305
# 2024-04-16 15:39:11,380 [ERROR] Base - Something went wrong: HTTPSConnectionPool(host='amp-api.apps.apple.com', port=443): Max retries exceeded with url: /v1/catalog/kr/apps/416048305/reviews?l=en-GB&offset=0&limit=20&platform=web&additionalPlatforms=appletv%2Cipad%2Ciphone%2Cmac (Caused by ResponseError('too many 429 error responses'))
# 2024-04-16 15:39:11,382 [INFO] Base - [id:416048305] Fetched 0 reviews (0 fetched in total)
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [03:02<00:00, 91.33s/it]
# Done

# %%
app_store_reviews[app_store_reviews['camera_app'] == 'snow']
# Out:
#                     date                                             review  \
# 0    2018-08-06 02:39:20                           사진 찍는데 재미있게 찍을 수 있어서 좋아요
# 1    2018-10-23 00:57:57  이번 업데이트 이후로 아이폰6로 어플 들어가자마자 튕긴다\n백그라운드에도 아무것도 ...
# 2    2018-09-03 12:03:57                                      스노우 감사해야 사랑해요
# 3    2018-12-18 09:13:49  다 필요 없고요 p3필터 갑자기 왜 없앤거죠 그 필터 제가 가장 애정하는데 그러면 ...
# 4    2018-11-14 12:44:26                    자꾸 화면을 킬때마다 멈춰요.다른 필터나 스티커는 짱!!
# ...                  ...                                                ...
# 6675 2018-10-28 16:31:27  자꾸 앱 킬때마다 화면이 멈추고 카메라 반응속도가 너무 느려요ㅜㅜ다시 껐다켜보고 지...
# 6676 2020-01-03 02:54:33  제가 해외에 살고 있긴 하지만 국내에서 있을 때도 스노우도 매번 써왔었는데요, 해외...
# 6677 2018-01-25 17:16:36  정말 가장 애정하고 자주 사용하는 카메라 어플이에요! 스티커로 얼굴도 꾸밀 수 있고...
# 6678 2023-02-17 07:23:17  기기상의 문제인지는 모르겠는데 아이폰8유저입니다. 항상 스노우앱은 한번씩 앱이 종료...
# 6679 2023-04-25 10:16:59  진짜 스노우 너무 좋고 잘 쓰고있는데 스노우는 발열이 너무 심하고 자꾸 튕겨요ㅠㅠㅠ...
#
#       rating isEdited           userName                    title  \
# 0        5.0    False             binitt                       최고
# 1        1.0    False    사과로넘어온날20180503               아이폰6 튕김오진다
# 2        5.0    False            강남역현정잉임          이런 조은어플이 무료라니ㅜㅜ
# 3        1.0    False                서현😺                       필터
# 4        4.0    False              예서나으리                      버그?
# ...      ...      ...                ...                      ...
# 6675     5.0    False              배추라오요  아이폰6 사용자인데 버그 수정 안될까요ㅜㅜ
# 6676     3.0    False          별각디이ㅔ1538                  개선해주세요!
# 6677     5.0    False               💗러블💗            추가됐으면 하는 한가지!
# 6678     5.0    False          어쩔티비저쩔티비요              별5개면 보겠죠???
# 6679     4.0    False  ㄹㄹ쑈ㅛㄹㄹㄲㅆㅇㄴㄴㄷㅎㅊㅊ초ㅓ           다 좋은데..튕김현상이..
#
#      developerResponse camera_app
# 0                  NaN       snow
# 1                  NaN       snow
# 2                  NaN       snow
# 3                  NaN       snow
# 4                  NaN       snow
# ...                ...        ...
# 6675               NaN       snow
# 6676               NaN       snow
# 6677               NaN       snow
# 6678               NaN       snow
# 6679               NaN       snow
#
# [6680 rows x 8 columns]

# %%
app_store_reviews[app_store_reviews['camera_app'] == 'meitu']
# Out:
# Empty DataFrame
# Columns: [date, review, rating, isEdited, userName, title, developerResponse, camera_app]
# Index: []

# %%
app_store_reviews.to_excel('snow_review.xlsx')
